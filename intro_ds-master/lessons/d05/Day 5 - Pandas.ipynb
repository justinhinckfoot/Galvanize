# %%
import pandas as pd

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.DataFrame?

# %%
pd.DataFrame([{'a': 1, 'b': 2, 'c': 3}
            ,{'a': 4, 'b': 5, 'c': 6, 'd': 7}])
# Out:
#    a  b  c    d
# 0  1  2  3  NaN
# 1  4  5  6  7.0

# %%
pd.DataFrame({'a': [1,4],'b': [2, 5], 'c': [3, 6], 'd': [pd.np.NaN, 7]})
# Out:
#    a  b  c    d
# 0  1  2  3  NaN
# 1  4  5  6  7.0

# %%
pd.read_csv?

# %%
# %ls data
# Out:
# winequality-red.csv  winequality-white.csv

# %%
pd.read_csv('data/winequality-red.csv',delimiter=';')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# ...

# %%
df = pd.read_csv('data/winequality-red.csv',delimiter=';')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# ...

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1599, step=1)

# %%
df.set_index('fixed acidity')
# Out:
#                volatile acidity  citric acid  residual sugar  chlorides  \
# fixed acidity
# 7.4                       0.700         0.00             1.9      0.076
# 7.8                       0.880         0.00             2.6      0.098
# 7.8                       0.760         0.04             2.3      0.092
# 11.2                      0.280         0.56             1.9      0.075
# 7.4                       0.700         0.00             1.9      0.076
# 7.4                       0.660         0.00             1.8      0.075
# 7.9                       0.600         0.06             1.6      0.069
# 7.3                       0.650         0.00             1.2      0.065
# 7.8                       0.580         0.02             2.0      0.073
# 7.5                       0.500         0.36             6.1      0.071
# 6.7                       0.580         0.08             1.8      0.097
# 7.5                       0.500         0.36             6.1      0.071
# ...

# %%
ca = df['citric acid']

# %%
ca
# Out:
# 0       0.00
# 1       0.00
# 2       0.04
# 3       0.56
# 4       0.00
# 5       0.00
# 6       0.06
# 7       0.00
# 8       0.02
# 9       0.36
# 10      0.08
# 11      0.36
# 12      0.00
# 13      0.29
# 14      0.18
# 15      0.19
# 16      0.56
# 17      0.28
# 18      0.08
# 19      0.51
# 20      0.48
# 21      0.31
# 22      0.21
# 23      0.11
# 24      0.14
# 25      0.16
# 26      0.24
# 27      0.21
# 28      0.00
# 29      0.00
#         ...
# 1569    0.14
# 1570    0.53
# 1571    0.14
# 1572    0.32
# 1573    0.20
# 1574    0.78
# 1575    0.40
# 1576    0.63
# 1577    0.15
# 1578    0.15
# 1579    0.09
# 1580    0.33
# 1581    0.09
# 1582    0.10
# 1583    0.29
# 1584    0.44
# 1585    0.44
# 1586    0.41
# 1587    0.11
# 1588    0.33
# 1589    0.20
# 1590    0.15
# 1591    0.09
# 1592    0.13
# 1593    0.08
# 1594    0.08
# 1595    0.10
# 1596    0.13
# 1597    0.12
# 1598    0.47
# Name: citric acid, Length: 1599, dtype: float64

# %%
ca.mean()
# Out:
# 0.2709756097560964

# %%
ca.min()
# Out:
# 0.0

# %%
ca.max()
# Out:
# 1.0

# %%
ca.std()
# Out:
# 0.19480113740531785

# %%
ca.sem()
# Out:
# 0.004871551032773753

# %%
ca.describe()
# Out:
# count    1599.000000
# mean        0.270976
# std         0.194801
# min         0.000000
# 25%         0.090000
# 50%         0.260000
# 75%         0.420000
# max         1.000000
# Name: citric acid, dtype: float64

# %%
ca.describe()['min']
# Out:
# 0.0

# %%
ca.describe()['std']
# Out:
# 0.19480113740531785

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %%
df.head(1)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4               0.7          0.0             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5

# %%
df[['citric acid', 'chlorides', 'density']]
# Out:
#       citric acid  chlorides  density
# 0            0.00      0.076  0.99780
# 1            0.00      0.098  0.99680
# 2            0.04      0.092  0.99700
# 3            0.56      0.075  0.99800
# 4            0.00      0.076  0.99780
# 5            0.00      0.075  0.99780
# 6            0.06      0.069  0.99640
# 7            0.00      0.065  0.99460
# 8            0.02      0.073  0.99680
# 9            0.36      0.071  0.99780
# 10           0.08      0.097  0.99590
# 11           0.36      0.071  0.99780
# 12           0.00      0.089  0.99430
# 13           0.29      0.114  0.99740
# 14           0.18      0.176  0.99860
# 15           0.19      0.170  0.99860
# 16           0.56      0.092  0.99690
# 17           0.28      0.368  0.99680
# 18           0.08      0.086  0.99740
# 19           0.51      0.341  0.99690
# 20           0.48      0.077  0.99680
# 21           0.31      0.082  0.99820
# 22           0.21      0.106  0.99660
# 23           0.11      0.084  0.99680
# ...

# %%
df.loc[1591]
# Out:
# fixed acidity            5.40000
# volatile acidity         0.74000
# citric acid              0.09000
# residual sugar           1.70000
# chlorides                0.08900
# free sulfur dioxide     16.00000
# total sulfur dioxide    26.00000
# density                  0.99402
# pH                       3.67000
# sulphates                0.56000
# alcohol                 11.60000
# quality                  6.00000
# Name: 1591, dtype: float64

# %%
df.loc[1591:1591]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1591            5.4              0.74         0.09             1.7      0.089
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1591                 16.0                  26.0  0.99402  3.67       0.56
#
#       alcohol  quality
# 1591     11.6        6

# %%
def fixrow(row):
    row['a'] = row['a'] / 3.0
    row['b'] = row['b']
    row['d'] = pd.np.NaN
    return row

# %%
exdf = pd.DataFrame([{'a': 1, 'b': 2, 'c': 3}
            ,{'a': 4, 'b': 5, 'c': 6, 'd': 7}])

# %%
exdf
# Out:
#    a  b  c    d
# 0  1  2  3  NaN
# 1  4  5  6  7.0

# %%
exdf.apply(fixrow,axis=1)
# Out:
#           a    b    c   d
# 0  0.333333  2.0  3.0 NaN
# 1  1.333333  5.0  6.0 NaN

# %%
import gc

# %%
gc.collect()
# Out:
# 152

# %%
df.loc[1590:1595]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1590            6.3              0.55         0.15             1.8      0.077
# 1591            5.4              0.74         0.09             1.7      0.089
# 1592            6.3              0.51         0.13             2.3      0.076
# 1593            6.8              0.62         0.08             1.9      0.068
# 1594            6.2              0.60         0.08             2.0      0.090
# 1595            5.9              0.55         0.10             2.2      0.062
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1590                 26.0                  35.0  0.99314  3.32       0.82
# 1591                 16.0                  26.0  0.99402  3.67       0.56
# 1592                 29.0                  40.0  0.99574  3.42       0.75
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.describe()['mean':'min']
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# mean       8.319637          0.527821     0.270976        2.538806   0.087467
# std        1.741096          0.179060     0.194801        1.409928   0.047065
# min        4.600000          0.120000     0.000000        0.900000   0.012000
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# mean            15.874922             46.467792  0.996747  3.311113
# std             10.460157             32.895324  0.001887  0.154386
# min              1.000000              6.000000  0.990070  2.740000
#
#       sulphates    alcohol   quality
# mean   0.658149  10.422983  5.636023
# std    0.169507   1.065668  0.807569
# min    0.330000   8.400000  3.000000

# %%
df.describe()['mean':'min':2]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# mean       8.319637          0.527821     0.270976        2.538806   0.087467
# min        4.600000          0.120000     0.000000        0.900000   0.012000
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# mean            15.874922             46.467792  0.996747  3.311113
# min              1.000000              6.000000  0.990070  2.740000
#
#       sulphates    alcohol   quality
# mean   0.658149  10.422983  5.636023
# min    0.330000   8.400000  3.000000

# %%
df.describe()['mean':'min':2]['chlorides']
# Out:
# mean    0.087467
# min     0.012000
# Name: chlorides, dtype: float64

# %%
df.describe()['mean':'min':2]['chlorides']['mean']
# Out:
# 0.08746654158849257

# %% [markdown]
# ## Select the wines with volatile acidity less than 0.58 and obtain the mean density

# %%
df.loc['volatile acidity'] > 0.58
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [volatile acidity] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-4b4542164584> in <module>()
# ----> 1 df.loc['volatile acidity'] > 0.58
#
# ...

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# ...

# %%
v = df['volatile acidity']

# %%
v[v < 0.58].mean()
# Out:
# 0.4136349534643229

# %%
df[df['volatile acidity'] < 0.58]['density'].mean()
# Out:
# 0.9967050155118923

# %%
df['residual sugar'] >= 6
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9        True
# 10      False
# 11       True
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1569    False
# 1570    False
# 1571    False
# 1572    False
# 1573    False
# 1574     True
# 1575    False
# 1576    False
# 1577    False
# 1578    False
# 1579    False
# 1580    False
# 1581    False
# 1582    False
# 1583    False
# 1584    False
# 1585    False
# 1586    False
# 1587    False
# 1588    False
# 1589     True
# 1590    False
# 1591    False
# 1592    False
# 1593    False
# 1594    False
# 1595    False
# 1596    False
# 1597    False
# 1598    False
# ...

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# ...

# %%
(df['residual sugar'] >= 1.6) & (df['volatile acidity'] < .5)
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16       True
# 17      False
# 18      False
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25      False
# 26       True
# 27       True
# 28      False
# 29      False
#         ...
# 1569    False
# 1570     True
# 1571     True
# 1572    False
# 1573    False
# 1574     True
# 1575    False
# 1576     True
# 1577    False
# 1578    False
# 1579    False
# 1580     True
# 1581    False
# 1582    False
# 1583     True
# 1584     True
# 1585     True
# 1586     True
# 1587    False
# 1588    False
# 1589    False
# 1590    False
# 1591    False
# 1592    False
# 1593    False
# 1594    False
# 1595    False
# 1596    False
# 1597    False
# 1598     True
# ...

# %%
names = df.columns

# %%
names
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
[name.replace(' ','_') for name in names]
# Out:
# ['fixed_acidity',
#  'volatile_acidity',
#  'citric_acid',
#  'residual_sugar',
#  'chlorides',
#  'free_sulfur_dioxide',
#  'total_sulfur_dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
df.columns = [name.replace(' ','_') for name in names]

# %%
df
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# ...

# %%
df.loc[6, 'chlorides']
# Out:
# 0.069

# %%
df.loc[6, 'chlorides'] = 10

# %%
df.loc[6, 'chlorides']
# Out:
# 10.0

# %%
df.columns
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df['free_sulfur_dioxide'] / df['total_sulfur_dioxide']
# Out:
# 0       0.323529
# 1       0.373134
# 2       0.277778
# 3       0.283333
# 4       0.323529
# 5       0.325000
# 6       0.254237
# 7       0.714286
# 8       0.500000
# 9       0.166667
# 10      0.230769
# 11      0.166667
# 12      0.271186
# 13      0.310345
# 14      0.358621
# 15      0.344595
# 16      0.339806
# 17      0.285714
# 18      0.206897
# 19      0.303571
# 20      0.483333
# 21      0.323944
# 22      0.270270
# 23      0.134328
# 24      0.525000
# 25      0.478261
# 26      0.363636
# 27      0.270270
# 28      0.400000
# 29      0.500000
#           ...
# 1569    0.441176
# 1570    0.542857
# 1571    0.600000
# 1572    0.336538
# 1573    0.300000
# 1574    0.250000
# 1575    0.600000
# 1576    0.551724
# 1577    0.481481
# 1578    0.650000
# 1579    0.750000
# 1580    0.346154
# 1581    0.750000
# 1582    0.481481
# 1583    0.326531
# 1584    0.705882
# 1585    0.458333
# 1586    0.566667
# 1587    0.642857
# 1588    0.333333
# 1589    0.367089
# ...

# %%
df['frac_free_sulfer_dioxide'] = df['free_sulfur_dioxide'] / df['total_sulfur_dioxide']

# %%
df
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6     10.000
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# ...

# %%
df.groupby('quality').mean()
# Out:
#          fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# quality
# 3             8.360000          0.884500     0.171000        2.635000
# 4             7.779245          0.693962     0.174151        2.694340
# 5             8.167254          0.577041     0.243686        2.528855
# 6             8.347179          0.497484     0.273824        2.477194
# 7             8.872362          0.403920     0.375176        2.720603
# 8             8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide   density  \
# quality
# 3         0.122500            11.000000             24.900000  0.997464
# 4         0.090679            12.264151             36.245283  0.996542
# 5         0.107319            16.983847             56.513950  0.997104
# 6         0.084956            15.711599             40.869906  0.996615
# 7         0.076588            14.045226             35.020101  0.996104
# ...

# %%
# %matplotlib inline

# %%
df.groupby('quality')['fixed_acidity'].plot(kind='hist', legend=True)
# Out:
# quality
# 3    AxesSubplot(0.125,0.125;0.775x0.755)
# 4    AxesSubplot(0.125,0.125;0.775x0.755)
# 5    AxesSubplot(0.125,0.125;0.775x0.755)
# 6    AxesSubplot(0.125,0.125;0.775x0.755)
# 7    AxesSubplot(0.125,0.125;0.775x0.755)
# 8    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: fixed_acidity, dtype: object

# %%
df.groupby('quality')['fixed_acidity'].plot(kind='kde', legend=True)
# Out:
# quality
# 3    AxesSubplot(0.125,0.125;0.775x0.755)
# 4    AxesSubplot(0.125,0.125;0.775x0.755)
# 5    AxesSubplot(0.125,0.125;0.775x0.755)
# 6    AxesSubplot(0.125,0.125;0.775x0.755)
# 7    AxesSubplot(0.125,0.125;0.775x0.755)
# 8    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: fixed_acidity, dtype: object

# %%
df.groupby('quality').count()
# Out:
#          fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# quality
# 3                   10                10           10              10
# 4                   53                53           53              53
# 5                  681               681          681             681
# 6                  638               638          638             638
# 7                  199               199          199             199
# 8                   18                18           18              18
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density   pH  \
# quality
# 3               10                   10                    10       10   10
# 4               53                   53                    53       53   53
# 5              681                  681                   681      681  681
# 6              638                  638                   638      638  638
# 7              199                  199                   199      199  199
# ...

# %%
df['fixed_acidity'].plot(kind='kde')
